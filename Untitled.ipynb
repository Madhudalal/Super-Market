# %%
import numpy as np
import pandas as pd
import matplotlib .pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('supermarket_sales - Sheet1.csv')
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
total=(df['Unit price']*df['Quantity']+df['Tax 5%'])
total
# Out:
# 0       548.9715
# 1        80.2200
# 2       340.5255
# 3       489.0480
# 4       634.3785
#          ...
# 995      42.3675
# 996    1022.4900
# 997      33.4320
# 998      69.1110
# 999     649.2990
# Length: 1000, dtype: float64

# %%
gross_margin=(df['Total']-df['cogs'])/(df['Total']*100)
gross_margin
# Out:
# 0      0.000476
# 1      0.000476
# 2      0.000476
# 3      0.000476
# 4      0.000476
#          ...
# 995    0.000476
# 996    0.000476
# 997    0.000476
# 998    0.000476
# 999    0.000476
# Length: 1000, dtype: float64

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df.describe(include='O')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
#
#             Date   Time  Payment
# count       1000   1000     1000
# unique        89    506        3
# top     2/7/2019  19:48  Ewallet
# freq          20      7      345

# %%
# find object in dataset
obj=[i for i in df if df[i].dtype=='O']
print('the object variables are: ',obj)
# Out:
# the object variables are:  ['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender', 'Product line', 'Date', 'Time', 'Payment']

# %%
numerical=[col for col in df if df[col].dtype!='O']
print('the numerical variable are: ',numerical)
# Out:
# the numerical variable are:  ['Unit price', 'Quantity', 'Tax 5%', 'Total', 'cogs', 'gross margin percentage', 'gross income', 'Rating']

# %%
for i in obj:
    if i!='Invoice ID' and i!='Date' and i!='Time':
        print(i,'.....',df[i].nunique(),'.....',df[i].unique())
        print(i,'............',df[i].value_counts())
# Out:
# Branch ..... 3 ..... ['A' 'C' 'B']
# Branch ............ A    340
# B    332
# C    328
# Name: Branch, dtype: int64
# City ..... 3 ..... ['Yangon' 'Naypyitaw' 'Mandalay']
# City ............ Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64
# Customer type ..... 2 ..... ['Member' 'Normal']
# Customer type ............ Member    501
# Normal    499
# Name: Customer type, dtype: int64
# Gender ..... 2 ..... ['Female' 'Male']
# Gender ............ Female    501
# Male      499
# Name: Gender, dtype: int64
# Product line ..... 6 ..... ['Health and beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories']
# Product line ............ Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64
# ...

# %%
z=df.select_dtypes(include='O')
z
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line       Date   Time      Payment
# 0         Health and beauty   1/5/2019  13:08      Ewallet
# 1    Electronic accessories   3/8/2019  10:29         Cash
# 2        Home and lifestyle   3/3/2019  13:23  Credit card
# ...

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Date           1000 non-null   object
#  7   Time           1000 non-null   object
#  8   Payment        1000 non-null   object
# dtypes: object(9)
# memory usage: 70.4+ KB

# %%
plt.figure(figsize=(22,6))
c=1
for i in z:
    if i!='Invoice ID' and i!='Date' and i!='Time' and i!='Product line':
        plt.subplot(1,5,c)
        sns.countplot(x=z[i],data=z)
        plt.xticks(rotation=90,fontsize=15)
        c+=1
plt.show()

sns.countplot(x=z['Product line'],data=z)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Health and beauty'),
#   Text(1, 0, 'Electronic accessories'),
#   Text(2, 0, 'Home and lifestyle'),
#   Text(3, 0, 'Sports and travel'),
#   Text(4, 0, 'Food and beverages'),
#   Text(5, 0, 'Fashion accessories')])

# %%
plt.figure(figsize=(22,6))
plt.subplot(1,5,1)
sns.countplot(x='Branch',data=z)
plt.subplot(1,5,2)
sns.countplot(x='City',data=z)
plt.subplot(1,5,3)
sns.countplot(x='Customer type',data=z)
plt.subplot(1,5,4)
sns.countplot(x='Gender',data=z)
plt.subplot(1,5,5)
sns.countplot(x='Payment',data=z)

plt.show()

# %%
k=df.groupby(['Product line','Branch'])['gross income'].agg(['count','sum']).reset_index()
k
# Out:
#               Product line Branch  count        sum
# 0   Electronic accessories      A     60   872.2435
# 1   Electronic accessories      B     55   811.9735
# 2   Electronic accessories      C     55   903.2845
# 3      Fashion accessories      A     51   777.7385
# 4      Fashion accessories      B     62   781.5865
# 5      Fashion accessories      C     65  1026.6700
# 6       Food and beverages      A     58   817.2905
# 7       Food and beverages      B     50   724.5185
# 8       Food and beverages      C     66  1131.7550
# 9        Health and beauty      A     47   599.8930
# 10       Health and beauty      B     53   951.4600
# 11       Health and beauty      C     52   791.2060
# 12      Home and lifestyle      A     65  1067.4855
# 13      Home and lifestyle      B     50   835.6745
# 14      Home and lifestyle      C     45   661.6930
# 15       Sports and travel      A     59   922.5095
# 16       Sports and travel      B     62   951.8190
# ...

# %%
sns.barplot(x='Product line',y='sum',hue='Branch',data=k)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Electronic accessories'),
#   Text(1, 0, 'Fashion accessories'),
#   Text(2, 0, 'Food and beverages'),
#   Text(3, 0, 'Health and beauty'),
#   Text(4, 0, 'Home and lifestyle'),
#   Text(5, 0, 'Sports and travel')])

# %%
# insight 1: which is the best selling branch

# %%
l=df.groupby('Branch')['gross income'].sum().reset_index()
l
# Out:
#   Branch  gross income
# 0      A     5057.1605
# 1      B     5057.0320
# 2      C     5265.1765

# %%
sns.barplot(x='Branch',y='gross income',data=l);

# %%
plt.pie('gross income',labels='Branch',data=l,autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1dfed287430>,
# ...
#  [Text(0.5634291868056724, 0.9447473479483809, 'A'),
#   Text(-1.0990070798395741, 0.04672727749924972, 'B'),
#   Text(0.5227882673793595, -0.9678287180542265, 'C')],
#  [Text(0.3073250109849122, 0.5153167352445713, '32.88%'),
#   Text(-0.5994584071852223, 0.025487605908681665, '32.88%'),
#   Text(0.28515723675237786, -0.5279065734841235, '34.24%')])

# %%
# insight 2: which branch has high rating

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.groupby('Branch')['Rating'].sum().reset_index()
# Out:
#   Branch  Rating
# 0      A  2389.2
# 1      B  2263.6
# 2      C  2319.9

# %%
sns.barplot(x='Branch',y='Rating',data=df,ci=None)
# Out:
# C:\Users\Madhu\AppData\Local\Temp\ipykernel_20380\3509687090.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Branch',y='Rating',data=df,ci=None)
# <Axes: xlabel='Branch', ylabel='Rating'>

# %%
c=df[df['Branch']=='C']
c
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 20   300-71-4605      C  Naypyitaw        Member    Male
# 34   183-56-6882      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 984  189-40-5216      C  Naypyitaw        Normal    Male
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 5    Electronic accessories       85.39         7  29.8865  627.6165
# 7        Home and lifestyle       73.56        10  36.7800  772.3800
# ...

# %%
# insight 3: clearify gross income based on customer type ?

# %%
c.groupby('Customer type')['gross income'].sum().reset_index()
# Out:
#   Customer type  gross income
# 0        Member     2708.6325
# 1        Normal     2556.5440

# %%
c['Customer type'].value_counts()
# Out:
# Member    169
# Normal    159
# Name: Customer type, dtype: int64

# %%
sns.countplot(x='Customer type',data=c);

# %%
# insight 4: which days has most gross income

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Days']=df['Date'].dt.day_name()

# %%
df['Months']=df['Date'].dt.month_name()

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.groupby(['Days'])['gross income'].sum().reset_index()
# Out:
#         Days  gross income
# 0     Friday     2091.7305
# 1     Monday     1804.7180
# 2   Saturday     2672.4195
# 3     Sunday     2117.0425
# 4   Thursday     2159.4880
# 5    Tuesday     2451.5355
# 6  Wednesday     2082.4350

# %%
i=df.groupby(['Months','Days'])['gross income'].sum().reset_index().sort_values(by='gross income',ascending=False)
i
# Out:
#       Months       Days  gross income
# 16     March   Saturday     1227.1870
# 12   January    Tuesday     1009.7385
# 11   January   Thursday      924.5895
# 9    January   Saturday      861.6040
# 13   January  Wednesday      848.0180
# 19     March    Tuesday      838.6350
# 0   February     Friday      800.1090
# 3   February     Sunday      791.9515
# 14     March     Friday      757.3600
# 10   January     Sunday      683.6550
# 8    January     Monday      675.8415
# 20     March  Wednesday      643.6775
# 17     March     Sunday      641.4360
# 1   February     Monday      632.6150
# 4   February   Thursday      627.2885
# 18     March   Thursday      607.6100
# 5   February    Tuesday      603.1620
# 6   February  Wednesday      590.7395
# 2   February   Saturday      583.6285
# 7    January     Friday      534.2615
# 15     March     Monday      496.2615

# %%
df.groupby(['Days','Months'])['gross income'].sum().reset_index().sort_values(by='gross income',ascending=False)
# Out:
#          Days    Months  gross income
# 8    Saturday     March     1227.1870
# 16    Tuesday   January     1009.7385
# 13   Thursday   January      924.5895
# 7    Saturday   January      861.6040
# 19  Wednesday   January      848.0180
# 17    Tuesday     March      838.6350
# 0      Friday  February      800.1090
# 9      Sunday  February      791.9515
# 2      Friday     March      757.3600
# 10     Sunday   January      683.6550
# 4      Monday   January      675.8415
# 20  Wednesday     March      643.6775
# 11     Sunday     March      641.4360
# 3      Monday  February      632.6150
# 12   Thursday  February      627.2885
# 14   Thursday     March      607.6100
# 15    Tuesday  February      603.1620
# 18  Wednesday  February      590.7395
# 6    Saturday  February      583.6285
# 1      Friday   January      534.2615
# 5      Monday     March      496.2615

# %%
sns.barplot(x='Days',y='gross income',hue='Months',data=i,ci=None)
plt.xticks(rotation=90);
# Out:
# C:\Users\Madhu\AppData\Local\Temp\ipykernel_20380\2643851315.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Days',y='gross income',hue='Months',data=i,ci=None)

# %%
# insight 5: what mode of payment is high

# %%
sns.countplot(x='Payment',data=c);

# %%
c['Payment'].value_counts()
# Out:
# Cash           124
# Ewallet        106
# Credit card     98
# Name: Payment, dtype: int64

# %%
c.groupby(['Gender','Customer type'])['gross income'].sum()
# Out:
# Gender  Customer type
# Female  Member           1650.1640
#         Normal           1287.2390
# Male    Member           1058.4685
#         Normal           1269.3050
# Name: gross income, dtype: float64

# %%
sns.catplot(x='Payment',hue='Gender',kind='count',col='Customer type',data=c);

# %%
#insight 6: calculate the grpss income w.r.t. product line

# %%
products=c.groupby('Product line')['gross income'].sum().reset_index()
products
# Out:
#              Product line  gross income
# 0  Electronic accessories      903.2845
# 1     Fashion accessories     1026.6700
# 2      Food and beverages     1131.7550
# 3       Health and beauty      791.2060
# 4      Home and lifestyle      661.6930
# 5       Sports and travel      750.5680

# %%
sns.barplot(x='Product line',y='gross income',data=products)
plt.xticks(rotation=90);

# %%
# insight 7: Availability of the products

# %%
c['Product line'].value_counts(normalize=True)*100
# Out:
# Food and beverages        20.121951
# Fashion accessories       19.817073
# Electronic accessories    16.768293
# Health and beauty         15.853659
# Home and lifestyle        13.719512
# Sports and travel         13.719512
# Name: Product line, dtype: float64

# %%
c_index=c['Product line'].value_counts().index
c_index
# Out:
# Index(['Food and beverages', 'Fashion accessories', 'Electronic accessories',
#        'Health and beauty', 'Home and lifestyle', 'Sports and travel'],
#       dtype='object')

# %%
c_values=c['Product line'].value_counts().values
c_values
# Out:
# array([66, 65, 55, 52, 45, 45], dtype=int64)

# %%
plt.pie(c_values,labels=c_index,autopct='%0.2f%%');
